# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("sortingmethods.csv")
data.drop(columns=['Test'], inplace=True)
data.describe()
# Out:
#        Bubble Sort  Selection Sort  Insertion Sort  Bucket Sort  Merge Sort
# count   500.000000      500.000000      500.000000   500.000000  500.000000
# mean      6.527465        2.848002        2.768044     0.006323    0.026221
# std       0.181477        0.112387        0.120837     0.002815    0.002814
# min       6.251417        2.651047        2.605054     0.004843    0.023597
# 25%       6.443213        2.786798        2.716420     0.005195    0.025075
# 50%       6.501530        2.836691        2.760979     0.005250    0.025403
# 75%       6.569362        2.894726        2.813188     0.005338    0.026015
# max       8.140120        4.549944        5.016287     0.017104    0.049505

# %%
sns.violinplot(data= data[["Selection Sort", "Insertion Sort"]])
# Out:
# <Axes: >

# %%
sns.violinplot(data= data[["Bucket Sort", "Merge Sort"]])
# Out:
# <Axes: >

# %%
sns.barplot(data= data[["Bubble Sort", "Selection Sort", "Insertion Sort", "Bucket Sort", "Merge Sort"]])
# Out:
# <Axes: >

# %%
sns.violinplot(data= data[["Bubble Sort", "Selection Sort", "Insertion Sort", "Bucket Sort", "Merge Sort"]])
# Out:
# <Axes: >
